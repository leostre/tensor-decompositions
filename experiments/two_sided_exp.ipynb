# %%
import sys
import os

# Правильный путь с учетом вложенности
correct_path = "/home/user/projects/tensor-decompositions/tensor-decompositions"
sys.path.insert(0, correct_path)

# Проверка
print("Обновленный sys.path:")
print(sys.path[0])
# Out:
# Обновленный sys.path:
# /home/user/projects/tensor-decompositions/tensor-decompositions

# %%
from tdecomp.matrix.decomposer import TwoSidedRandomSVD

# %%
import sys
import os
from typing import List, Dict, Tuple, Callable, Any
import torch
import time
import numpy as np
import matplotlib.pyplot as plt
import logging
from datetime import datetime

# %%
def setup_logging():
    os.makedirs("logs", exist_ok=True)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    log_file = f"logs/experiment_{timestamp}.txt"
    
    logging.basicConfig(
        level=logging.INFO,
        format="%(asctime)s - %(levelname)s - %(message)s",
        handlers=[
            logging.FileHandler(log_file),
            logging.StreamHandler()
        ]
    )
    return logging.getLogger(__name__)

logger = setup_logging()
torch.manual_seed(42)

# %%
RANDOM_INIT_METHODS = ['normal', 'ortho', 'iid_entries', 'lean_walsh', 'identity_copies']
N_REPEATS = 20
SQUARE_SIZES = [2**i for i in range(4, 13)]
RECTANGULAR_FIXED_DIM = 256
RECTANGULAR_VARIABLE_SIZES = [2**i for i in range(4, 13)]

class ExperimentRunner:
    def __init__(self, device: str = None):
        self.device = device or ("cuda" if torch.cuda.is_available() else "cpu")
        self.logger = logging.getLogger(__name__)
        if self.device == "cuda":
            torch.backends.cudnn.benchmark = True 
        
    def clear_cuda_cache(self):
        if self.device == "cuda":
            torch.cuda.empty_cache()
            torch.cuda.synchronize()
    
    def warmup(self):
        if self.device == "cuda":
            x = torch.randn(100, 100, device=self.device)
            for _ in range(10):
                _ = torch.linalg.svd(x)
            self.clear_cuda_cache()
        
    def run_method(
        self,
        method: Callable,
        matrix_generator: Callable,
        method_kwargs: Dict[str, Any] = None,
        n_repeats: int = 1
    ) -> List[Dict]:
        method_kwargs = method_kwargs or {}
        results = []
        
        for _ in range(n_repeats):
            self.clear_cuda_cache()
            X = matrix_generator()
            
            if self.device == "cuda":
                torch.cuda.synchronize()
            start_time = time.perf_counter()
            
            if method == torch.linalg.svd:
                U, S, Vh = method(X, full_matrices=False)
                X_approx = U @ torch.diag(S) @ Vh
            else:
                decomposer = method(**method_kwargs)
                U, S, Vh = decomposer.decompose(X)
                X_approx = decomposer._two_sided_compose(U, S, Vh)
            
            if self.device == "cuda":
                torch.cuda.synchronize()
            elapsed = time.perf_counter() - start_time
            
            error = torch.norm(X - X_approx).item()
            rel_error = error / torch.norm(X).item()
            rank = len(S)
            
            results.append({
                "shape": tuple(X.shape),
                "error": error,
                "relative_error": rel_error,
                "time": elapsed,
                "rank": rank
            })
        
        return results
    
    def aggregate_results(self, results: List[Dict]) -> Dict:
        return {
            "shape": results[0]["shape"],
            "error_mean": np.mean([r["error"] for r in results]),
            "error_std": np.std([r["error"] for r in results]),
            "time_mean": np.mean([r["time"] for r in results]),
            "time_std": np.std([r["time"] for r in results]),
            "rank_mean": np.mean([r["rank"] for r in results]),
            "rank_std": np.std([r["rank"] for r in results]),
            "raw_results": results
        }
    
    def generate_matrix(self, shape: Tuple[int, int]) -> Callable:
        def generator():
            return torch.randn(*shape, device=self.device, dtype=torch.float32)
        return generator
    
    def run_comparative_experiment(self):
        self.warmup()
        all_results = {method: [] for method in RANDOM_INIT_METHODS}
        baseline_results = []
        
        for i, size in enumerate(SQUARE_SIZES):
            logger.info(f"Processing square matrices {i+1}/{len(SQUARE_SIZES)} size {size}x{size}")
            matrix_gen = self.generate_matrix((size, size))
            
            logger.info("Running baseline SVD...")
            baseline = self.run_method(
                torch.linalg.svd,
                matrix_gen,
                n_repeats=N_REPEATS
            )
            baseline_results.append(self.aggregate_results(baseline))
            
            for method in RANDOM_INIT_METHODS:
                logger.info(f"Running {method} initialization...")
                results = self.run_method(
                    TwoSidedRandomSVD,
                    matrix_gen,
                    method_kwargs={"distortion_factor": 0.6, "random_init": method},
                    n_repeats=N_REPEATS
                )
                all_results[method].append(self.aggregate_results(results))
                self.clear_cuda_cache()
        
        for i, size in enumerate(RECTANGULAR_VARIABLE_SIZES):
            logger.info(f"Processing rectangular matrices {i+1}/{len(RECTANGULAR_VARIABLE_SIZES)} size {RECTANGULAR_FIXED_DIM}x{size}")
            matrix_gen = self.generate_matrix((RECTANGULAR_FIXED_DIM, size))
            
            for method in RANDOM_INIT_METHODS:
                logger.info(f"Running {method} initialization...")
                results = self.run_method(
                    TwoSidedRandomSVD,
                    matrix_gen,
                    method_kwargs={"distortion_factor": 0.6, "random_init": method},
                    n_repeats=N_REPEATS
                )
                all_results[method].append(self.aggregate_results(results))
                self.clear_cuda_cache()
        
        self.plot_results(all_results, baseline_results)
        self.save_results(all_results, baseline_results)
        return all_results, baseline_results
    
    def plot_results(self, method_results: Dict, baseline_results: List[Dict]):
        plt.figure(figsize=(12, 10))
        
        plt.subplot(2, 2, 1)
        for method, data in method_results.items():
            square_data = [d for d in data[:len(SQUARE_SIZES)]]
            sizes = [d["shape"][0] for d in square_data]
            errors = [d["error_mean"] for d in square_data]
            errors_std = [d["error_std"] for d in square_data]
            plt.errorbar(sizes, errors, yerr=errors_std, fmt='o-', label=method)
        
        sizes = [d["shape"][0] for d in baseline_results]
        errors = [d["error_mean"] for d in baseline_results]
        errors_std = [d["error_std"] for d in baseline_results]
        plt.errorbar(sizes, errors, yerr=errors_std, fmt='k--', label='SVD Baseline')
        
        plt.xlabel('Matrix Size (N×N)')
        plt.ylabel('Error')
        plt.title('Comparison of Errors (Square Matrices)')
        plt.legend()
        plt.grid(True)
        plt.xscale('log')
        plt.yscale('log')
        
        plt.subplot(2, 2, 2)
        for method, data in method_results.items():
            square_data = [d for d in data[:len(SQUARE_SIZES)]]
            sizes = [d["shape"][0] for d in square_data]
            times = [d["time_mean"] for d in square_data]
            times_std = [d["time_std"] for d in square_data]
            plt.errorbar(sizes, times, yerr=times_std, fmt='o-', label=method)
        
        sizes = [d["shape"][0] for d in baseline_results]
        times = [d["time_mean"] for d in baseline_results]
        times_std = [d["time_std"] for d in baseline_results]
        plt.errorbar(sizes, times, yerr=times_std, fmt='k--', label='SVD Baseline')
        
        plt.xlabel('Matrix Size (N×N)')
        plt.ylabel('Time (s)')
        plt.title('Comparison of Runtime (Square Matrices)')
        plt.legend()
        plt.grid(True)
        plt.xscale('log')
        plt.yscale('log')
        
        plt.subplot(2, 2, 3)
        for method, data in method_results.items():
            rect_data = [d for d in data[len(SQUARE_SIZES):]]
            sizes = [f"{d['shape'][0]}×{d['shape'][1]}" for d in rect_data]
            errors = [d["error_mean"] for d in rect_data]
            errors_std = [d["error_std"] for d in rect_data]
            plt.errorbar(range(len(sizes)), errors, yerr=errors_std, fmt='o-', label=method)
        
        plt.xticks(range(len(sizes)), sizes, rotation=45)
        plt.xlabel('Matrix Size (M×N)')
        plt.ylabel('Error')
        plt.title('Comparison of Errors (Rectangular Matrices)')
        plt.legend()
        plt.grid(True)
        plt.yscale('log')
        
        plt.tight_layout()
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        os.makedirs("visualizations", exist_ok=True)
        plt.savefig(f"visualizations/comparison_results_{timestamp}.png")
        plt.close()
    
    def save_results(self, method_results: Dict, baseline_results: List[Dict]):
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        os.makedirs("results", exist_ok=True)
            
        csv_filename = f"results/results_summary_{timestamp}.csv"
            
        rows = []
            
        for res in baseline_results:
            rows.append({
                    "matrix_shape": f"{res['shape'][0]}x{res['shape'][1]}",
                    "method": "svd_baseline",
                    "error_mean": res["error_mean"],
                    "error_std": res["error_std"],
                    "time_mean": res["time_mean"],
                    "time_std": res["time_std"],
                    "rank_mean": res["rank_mean"],
                    "rank_std": res["rank_std"],
                    "matrix_type": "square" if res["shape"][0] == res["shape"][1] else "rectangular",
                    "dim1": res["shape"][0],
                    "dim2": res["shape"][1]
                })
            
        for method, data in method_results.items():
            for res in data:
                rows.append({
                        "matrix_shape": f"{res['shape'][0]}x{res['shape'][1]}",
                        "method": method,
                        "error_mean": res["error_mean"],
                        "error_std": res["error_std"],
                        "time_mean": res["time_mean"],
                        "time_std": res["time_std"],
                        "rank_mean": res["rank_mean"],
                        "rank_std": res["rank_std"],
                        "matrix_type": "square" if res["shape"][0] == res["shape"][1] else "rectangular",
                        "dim1": res["shape"][0],
                        "dim2": res["shape"][1]
                    })
            
        import csv
        with open(csv_filename, 'w', newline='') as csvfile:
                fieldnames = [
                    'matrix_shape', 'method', 'error_mean', 'error_std',
                    'time_mean', 'time_std', 'rank_mean', 'rank_std',
                    'matrix_type', 'dim1', 'dim2'
                ]
                writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                
                writer.writeheader()
                writer.writerows(rows)
            
                txt_filename = f"results/results_summary_{timestamp}.txt"

        with open(txt_filename, "w") as f:
            f.write("=== EXPERIMENT RESULTS SUMMARY ===\n\n")
            f.write(f"Number of repeats: {N_REPEATS}\n")
            f.write(f"Device: {self.device}\n")
            f.write(f"CSV results saved to: {csv_filename}\n\n")
                
            matrix_shapes = set(row['matrix_shape'] for row in rows)
                
            for shape in sorted(matrix_shapes, key=lambda x: (int(x.split('x')[0]), int(x.split('x')[1]))):
                shape_rows = [row for row in rows if row['matrix_shape'] == shape]
                f.write(f"\n=== MATRIX SHAPE: {shape} ===\n")
                    
                sorted_rows = sorted(shape_rows, key=lambda x: (x['method'] != 'svd_baseline', x['method']))
                   
                for row in sorted_rows:
                    f.write(
                            f"{row['method']:<15} | "
                            f"Error: {row['error_mean']:.3e} ± {row['error_std']:.1e} | "
                            f"Time: {row['time_mean']:.3f} ± {row['time_std']:.3f}s | "
                            f"Rank: {row['rank_mean']:.1f} ± {row['rank_std']:.1f}\n"
                        )
            
        logger.info(f"Results saved to {csv_filename} (CSV) and {txt_filename} (text)")

# %%
runner = ExperimentRunner()
runner.run_comparative_experiment()
# Out:
# 2025-08-06 16:30:51,753 - INFO - Processing square matrices 1/9 size 16x16
# 2025-08-06 16:30:51,754 - INFO - Running baseline SVD...
# 2025-08-06 16:30:51,782 - INFO - Running normal initialization...
# 2025-08-06 16:30:51,816 - INFO - Running ortho initialization...
# 2025-08-06 16:30:51,861 - INFO - Running iid_entries initialization...
# 2025-08-06 16:30:51,897 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:30:51,931 - INFO - Running identity_copies initialization...
# 2025-08-06 16:30:51,971 - INFO - Processing square matrices 2/9 size 32x32
# 2025-08-06 16:30:51,971 - INFO - Running baseline SVD...
# 2025-08-06 16:30:51,995 - INFO - Running normal initialization...
# 2025-08-06 16:30:52,053 - INFO - Running ortho initialization...
# 2025-08-06 16:30:52,123 - INFO - Running iid_entries initialization...
# 2025-08-06 16:30:52,177 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:30:52,228 - INFO - Running identity_copies initialization...
# 2025-08-06 16:30:52,279 - INFO - Processing square matrices 3/9 size 64x64
# 2025-08-06 16:30:52,279 - INFO - Running baseline SVD...
# 2025-08-06 16:30:52,341 - INFO - Running normal initialization...
# 2025-08-06 16:30:52,482 - INFO - Running ortho initialization...
# 2025-08-06 16:30:52,646 - INFO - Running iid_entries initialization...
# 2025-08-06 16:30:52,784 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:30:52,937 - INFO - Running identity_copies initialization...
# 2025-08-06 16:30:53,085 - INFO - Processing square matrices 4/9 size 128x128
# 2025-08-06 16:30:53,086 - INFO - Running baseline SVD...
# 2025-08-06 16:30:53,209 - INFO - Running normal initialization...
# 2025-08-06 16:30:53,473 - INFO - Running ortho initialization...
# 2025-08-06 16:30:53,761 - INFO - Running iid_entries initialization...
# 2025-08-06 16:30:54,026 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:30:54,306 - INFO - Running identity_copies initialization...
# 2025-08-06 16:30:54,570 - INFO - Processing square matrices 5/9 size 256x256
# 2025-08-06 16:30:54,571 - INFO - Running baseline SVD...
# 2025-08-06 16:30:54,840 - INFO - Running normal initialization...
# 2025-08-06 16:30:55,375 - INFO - Running ortho initialization...
# 2025-08-06 16:30:55,997 - INFO - Running iid_entries initialization...
# 2025-08-06 16:30:56,572 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:30:57,134 - INFO - Running identity_copies initialization...
# 2025-08-06 16:30:57,696 - INFO - Processing square matrices 6/9 size 512x512
# 2025-08-06 16:30:57,696 - INFO - Running baseline SVD...
# 2025-08-06 16:30:58,306 - INFO - Running normal initialization...
# 2025-08-06 16:30:59,680 - INFO - Running ortho initialization...
# 2025-08-06 16:31:01,252 - INFO - Running iid_entries initialization...
# 2025-08-06 16:31:02,646 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:31:04,010 - INFO - Running identity_copies initialization...
# 2025-08-06 16:31:05,366 - INFO - Processing square matrices 7/9 size 1024x1024
# 2025-08-06 16:31:05,367 - INFO - Running baseline SVD...
# 2025-08-06 16:31:07,044 - INFO - Running normal initialization...
# 2025-08-06 16:31:10,823 - INFO - Running ortho initialization...
# 2025-08-06 16:31:15,805 - INFO - Running iid_entries initialization...
# 2025-08-06 16:31:19,831 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:31:26,098 - INFO - Running identity_copies initialization...
# 2025-08-06 16:31:29,925 - INFO - Processing square matrices 8/9 size 2048x2048
# 2025-08-06 16:31:29,925 - INFO - Running baseline SVD...
# 2025-08-06 16:31:34,871 - INFO - Running normal initialization...
# 2025-08-06 16:31:46,012 - INFO - Running ortho initialization...
# 2025-08-06 16:32:06,532 - INFO - Running iid_entries initialization...
# 2025-08-06 16:32:20,805 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:32:37,799 - INFO - Running identity_copies initialization...
# 2025-08-06 16:32:49,027 - INFO - Processing square matrices 9/9 size 4096x4096
# 2025-08-06 16:32:49,028 - INFO - Running baseline SVD...
# 2025-08-06 16:33:47,575 - INFO - Running normal initialization...
# 2025-08-06 16:35:25,176 - INFO - Running ortho initialization...
# 2025-08-06 16:37:20,204 - INFO - Running iid_entries initialization...
# 2025-08-06 16:39:00,153 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:40:43,012 - INFO - Running identity_copies initialization...
# 2025-08-06 16:42:16,765 - INFO - Processing rectangular matrices 1/9 size 256x16
# 2025-08-06 16:42:16,766 - INFO - Running normal initialization...
# 2025-08-06 16:42:16,841 - INFO - Running ortho initialization...
# 2025-08-06 16:42:16,967 - INFO - Running iid_entries initialization...
# 2025-08-06 16:42:17,072 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:42:17,168 - INFO - Running identity_copies initialization...
# 2025-08-06 16:42:17,261 - INFO - Processing rectangular matrices 2/9 size 256x32
# 2025-08-06 16:42:17,262 - INFO - Running normal initialization...
# 2025-08-06 16:42:17,351 - INFO - Running ortho initialization...
# 2025-08-06 16:42:17,495 - INFO - Running iid_entries initialization...
# 2025-08-06 16:42:17,617 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:42:17,733 - INFO - Running identity_copies initialization...
# 2025-08-06 16:42:17,846 - INFO - Processing rectangular matrices 3/9 size 256x64
# 2025-08-06 16:42:17,847 - INFO - Running normal initialization...
# 2025-08-06 16:42:17,972 - INFO - Running ortho initialization...
# 2025-08-06 16:42:18,158 - INFO - Running iid_entries initialization...
# 2025-08-06 16:42:18,322 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:42:20,896 - INFO - Running identity_copies initialization...
# 2025-08-06 16:42:21,057 - INFO - Processing rectangular matrices 4/9 size 256x128
# 2025-08-06 16:42:21,058 - INFO - Running normal initialization...
# 2025-08-06 16:42:21,258 - INFO - Running ortho initialization...
# 2025-08-06 16:42:21,495 - INFO - Running iid_entries initialization...
# 2025-08-06 16:42:21,707 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:42:21,922 - INFO - Running identity_copies initialization...
# 2025-08-06 16:42:22,130 - INFO - Processing rectangular matrices 5/9 size 256x256
# 2025-08-06 16:42:22,131 - INFO - Running normal initialization...
# 2025-08-06 16:42:22,459 - INFO - Running ortho initialization...
# 2025-08-06 16:42:22,848 - INFO - Running iid_entries initialization...
# 2025-08-06 16:42:23,199 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:42:23,547 - INFO - Running identity_copies initialization...
# 2025-08-06 16:42:23,877 - INFO - Processing rectangular matrices 6/9 size 256x512
# 2025-08-06 16:42:23,877 - INFO - Running normal initialization...
# 2025-08-06 16:42:24,225 - INFO - Running ortho initialization...
# 2025-08-06 16:42:24,671 - INFO - Running iid_entries initialization...
# 2025-08-06 16:42:25,048 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:42:25,425 - INFO - Running identity_copies initialization...
# 2025-08-06 16:42:25,781 - INFO - Processing rectangular matrices 7/9 size 256x1024
# 2025-08-06 16:42:25,781 - INFO - Running normal initialization...
# 2025-08-06 16:42:26,231 - INFO - Running ortho initialization...
# 2025-08-06 16:42:26,983 - INFO - Running iid_entries initialization...
# 2025-08-06 16:42:27,466 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:42:27,957 - INFO - Running identity_copies initialization...
# 2025-08-06 16:42:28,361 - INFO - Processing rectangular matrices 8/9 size 256x2048
# 2025-08-06 16:42:28,361 - INFO - Running normal initialization...
# 2025-08-06 16:42:29,113 - INFO - Running ortho initialization...
# 2025-08-06 16:42:31,483 - INFO - Running iid_entries initialization...
# 2025-08-06 16:42:32,616 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:42:33,779 - INFO - Running identity_copies initialization...
# 2025-08-06 16:42:34,470 - INFO - Processing rectangular matrices 9/9 size 256x4096
# 2025-08-06 16:42:34,470 - INFO - Running normal initialization...
# 2025-08-06 16:42:36,700 - INFO - Running ortho initialization...
# 2025-08-06 16:42:48,286 - INFO - Running iid_entries initialization...
# 2025-08-06 16:42:52,368 - INFO - Running lean_walsh initialization...
# 2025-08-06 16:43:00,716 - INFO - Running identity_copies initialization...
# 2025-08-06 16:43:02,945 - INFO - Results saved to results/results_summary_20250806_164302.csv (CSV) and results/results_summary_20250806_164302.txt (text)
# ({'normal': [{'shape': (16, 16),
#     'error_mean': np.float64(4.992703725292813e-05),
#     'error_std': np.float64(9.20203676976624e-06),
#     'time_mean': np.float64(0.0014157835003061336),
#     'time_std': np.float64(0.00023850400218086173),
#     'rank_mean': np.float64(16.0),
#     'rank_std': np.float64(0.0),
#     'raw_results': [{'shape': (16, 16),
#       'error': 5.331774809747003e-05,
#       'relative_error': 3.1427700697246117e-06,
#       'time': 0.0018028109989245422,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 5.1398321375017986e-05,
#       'relative_error': 3.288806061852986e-06,
#       'time': 0.0015719660004833713,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 3.941483737435192e-05,
#       'relative_error': 2.582847348802903e-06,
#       'time': 0.0012317350010562222,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 5.056538066128269e-05,
#       'relative_error': 3.1431737382691973e-06,
#       'time': 0.001682672998867929,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 5.7123983424389735e-05,
#       'relative_error': 3.564490867359978e-06,
#       'time': 0.0012292829997022636,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 5.325426900526509e-05,
#       'relative_error': 3.296110113812911e-06,
#       'time': 0.001215233001857996,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 4.282535155653022e-05,
#       'relative_error': 2.6039271939241727e-06,
#       'time': 0.001973869999346789,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 5.1511855417629704e-05,
#       'relative_error': 3.222008695626029e-06,
#       'time': 0.0013554559991462156,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 3.864278187393211e-05,
#       'relative_error': 2.4424979879623013e-06,
#       'time': 0.001255876002687728,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 6.452050001826137e-05,
#       'relative_error': 3.827406182782349e-06,
#       'time': 0.0011893949995283037,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 6.168327672639862e-05,
#       'relative_error': 3.6340853435821847e-06,
#       'time': 0.0012233429988555145,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 3.3324005926260725e-05,
#       'relative_error': 2.105210469707195e-06,
#       'time': 0.0012559700007841457,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 3.07824338960927e-05,
#       'relative_error': 1.9627655936121517e-06,
#       'time': 0.001230792000569636,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 4.7717683628434315e-05,
#       'relative_error': 3.0116656787431237e-06,
#       'time': 0.0012455969990696758,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 5.1219831220805645e-05,
#       'relative_error': 3.2387155621727917e-06,
#       'time': 0.0016719230006856378,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 4.760638330481015e-05,
#       'relative_error': 2.9596186431716876e-06,
#       'time': 0.0016235480034083594,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 6.251027662074193e-05,
#       'relative_error': 3.6182387533409547e-06,
#       'time': 0.0017171869985759258,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 4.9131151172332466e-05,
#       'relative_error': 3.245746998430273e-06,
#       'time': 0.0013630940011353232,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 4.936529148835689e-05,
#       'relative_error': 3.039112243369141e-06,
#       'time': 0.0012440880018402822,
#       'rank': 16},
#      {'shape': (16, 16),
#       'error': 6.262538227019832e-05,
#       'relative_error': 3.7944943010104636e-06,
#       'time': 0.0012318299995968118,
#       'rank': 16}]},
#    {'shape': (32, 32),
#     'error_mean': np.float64(0.00014967128226999192),
#     'error_std': np.float64(1.8440226198652002e-05),
#     'time_mean': np.float64(0.0026529314502113264),
#     'time_std': np.float64(0.0005245655511566437),
#     'rank_mean': np.float64(32.0),
#     'rank_std': np.float64(0.0),
#     'raw_results': [{'shape': (32, 32),
#       'error': 0.00014278771413955837,
#       'relative_error': 4.351407537987295e-06,
#       'time': 0.0037710220021835994,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00017561882850714028,
#       'relative_error': 5.683135268992309e-06,
#       'time': 0.0025099599988607224,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00015151259140111506,
#       'relative_error': 4.91294895068609e-06,
#       'time': 0.0023798269976396114,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00013455901353154331,
#       'relative_error': 4.167994073420897e-06,
#       'time': 0.002420093002001522,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00011549797636689618,
#       'relative_error': 3.8147936332613854e-06,
#       'time': 0.0024816699988150503,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.0001674895320320502,
#       'relative_error': 5.3579759414234666e-06,
#       'time': 0.002364361997024389,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00015940463345032185,
#       'relative_error': 4.889119070000928e-06,
#       'time': 0.003781299998081522,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00016273402434308082,
#       'relative_error': 5.195593837277154e-06,
#       'time': 0.0023961410006450024,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00016555096954107285,
#       'relative_error': 5.115483109053084e-06,
#       'time': 0.00236832299924572,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00016063307703007013,
#       'relative_error': 5.11613916630469e-06,
#       'time': 0.0024074559987639077,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00013969092105980963,
#       'relative_error': 4.3728684000450594e-06,
#       'time': 0.0023875600018072873,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00015157349116634578,
#       'relative_error': 4.545940721245365e-06,
#       'time': 0.0035936460008088034,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00015900669677648693,
#       'relative_error': 5.1196842308618705e-06,
#       'time': 0.002375300002313452,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.0001372068509226665,
#       'relative_error': 4.168863864680444e-06,
#       'time': 0.002435086000332376,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00010529983410378918,
#       'relative_error': 3.259799302698149e-06,
#       'time': 0.002313911998498952,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00014475912030320615,
#       'relative_error': 4.506825288607084e-06,
#       'time': 0.0023700199999439064,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.0001837237214203924,
#       'relative_error': 5.690972814133252e-06,
#       'time': 0.0024365950011997484,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00013589192531071603,
#       'relative_error': 4.26471410422423e-06,
#       'time': 0.003634005999629153,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.00014596327673643827,
#       'relative_error': 4.653563441319241e-06,
#       'time': 0.0023161750032159034,
#       'rank': 32},
#      {'shape': (32, 32),
#       'error': 0.0001545214472571388,
#       'relative_error': 4.844920110026266e-06,
#       'time': 0.0023161750032159034,
#       'rank': 32}]},
#    {'shape': (64, 64),
#     'error_mean': np.float64(0.0005622251483146101),
#     'error_std': np.float64(4.713274002177366e-05),
#     'time_mean': np.float64(0.006702547749591758),
#     'time_std': np.float64(0.0005574153551085735),
#     'rank_mean': np.float64(64.0),
#     'rank_std': np.float64(0.0),
#     'raw_results': [{'shape': (64, 64),
#       'error': 0.0006102657644078135,
#       'relative_error': 9.733418846032345e-06,
#       'time': 0.006523833999381168,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0005397637141868472,
#       'relative_error': 8.516476232538865e-06,
#       'time': 0.00646444700032589,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.000544919166713953,
#       'relative_error': 8.414297475536962e-06,
#       'time': 0.0069731289986521006,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0006532664992846549,
#       'relative_error': 1.0010424479000283e-05,
#       'time': 0.006840656998974737,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0005541079444810748,
#       'relative_error': 8.798637500753947e-06,
#       'time': 0.007644397999683861,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.000560201529879123,
#       'relative_error': 9.027723329510006e-06,
#       'time': 0.006120227997598704,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0006351295742206275,
#       'relative_error': 9.87056382123911e-06,
#       'time': 0.007381331000942737,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0005751813296228647,
#       'relative_error': 8.956581080916171e-06,
#       'time': 0.006142932001239387,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0005587390623986721,
#       'relative_error': 8.621375061859225e-06,
#       'time': 0.0071962289985094685,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0005053772474639118,
#       'relative_error': 7.892287620290967e-06,
#       'time': 0.006157660998724168,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0005516588571481407,
#       'relative_error': 8.604231766677003e-06,
#       'time': 0.006286755000473931,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.00047889561392366886,
#       'relative_error': 7.64546956515793e-06,
#       'time': 0.007457137002347736,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0004805735661648214,
#       'relative_error': 7.447213527519983e-06,
#       'time': 0.006329160998575389,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.000550406810361892,
#       'relative_error': 8.602659949186728e-06,
#       'time': 0.007083739998051897,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0005400954396463931,
#       'relative_error': 8.328638821393327e-06,
#       'time': 0.006065156001568539,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0005198555300012231,
#       'relative_error': 8.322016599126085e-06,
#       'time': 0.0071842189972812776,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0005489981267601252,
#       'relative_error': 8.704153619483342e-06,
#       'time': 0.006112628001574194,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0005982323782518506,
#       'relative_error': 9.41990035139557e-06,
#       'time': 0.0060746320014004596,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.0006134040886536241,
#       'relative_error': 9.603900601187634e-06,
#       'time': 0.007677327997953398,
#       'rank': 64},
#      {'shape': (64, 64),
#       'error': 0.000625430722720921,
#       'relative_error': 9.901720234170053e-06,
#       'time': 0.006335352998576127,
#       'rank': 64}]},
#    {'shape': (128, 128),
#     'error_mean': np.float64(0.003133341739885509),
#     'error_std': np.float64(0.00018350799205350647),
#     'time_mean': np.float64(0.012874614850443323),
#     'time_std': np.float64(0.0009340944987254946),
#     'rank_mean': np.float64(128.0),
#     'rank_std': np.float64(0.0),
#     'raw_results': [{'shape': (128, 128),
#       'error': 0.003304495010524988,
#       'relative_error': 2.5466160088552274e-05,
#       'time': 0.014917463002348086,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.003191247582435608,
#       'relative_error': 2.519198461155417e-05,
#       'time': 0.014938572003302397,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.0032630558125674725,
#       'relative_error': 2.537158793526037e-05,
#       'time': 0.014212418998795329,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.0032108938321471214,
#       'relative_error': 2.5428697989694313e-05,
#       'time': 0.014043921997654252,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.003013496519997716,
#       'relative_error': 2.3607446457723116e-05,
#       'time': 0.01240182299807202,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.0030043411534279585,
#       'relative_error': 2.3501059805797305e-05,
#       'time': 0.011643866000667913,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.00329714291729033,
#       'relative_error': 2.5539402911733214e-05,
#       'time': 0.012614883999049198,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.0027030380442738533,
#       'relative_error': 2.117644908177361e-05,
#       'time': 0.012441976999980398,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.0031778584234416485,
#       'relative_error': 2.4819077877241298e-05,
#       'time': 0.012504179001552984,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.003361715702340007,
#       'relative_error': 2.6445196745884763e-05,
#       'time': 0.01322732900007395,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.0033114654943346977,
#       'relative_error': 2.5721519551894467e-05,
#       'time': 0.011766205003368668,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.003133930964395404,
#       'relative_error': 2.4478148433127526e-05,
#       'time': 0.01257913900190033,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.003083161311224103,
#       'relative_error': 2.4063884318414577e-05,
#       'time': 0.012882266000815434,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.003054938977584243,
#       'relative_error': 2.3957385521719787e-05,
#       'time': 0.01282278500002576,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.003042921656742692,
#       'relative_error': 2.4023357035694802e-05,
#       'time': 0.012240456002473366,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.0033334787003695965,
#       'relative_error': 2.6093539217185184e-05,
#       'time': 0.012738535999233136,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.0032439755741506815,
#       'relative_error': 2.5417352932636374e-05,
#       'time': 0.011568904999876395,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.0032761376351118088,
#       'relative_error': 2.5472464279423222e-05,
#       'time': 0.01272512099967571,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.0027422539424151182,
#       'relative_error': 2.1174488579555246e-05,
#       'time': 0.012592648999998346,
#       'rank': 128},
#      {'shape': (128, 128),
#       'error': 0.002917285542935133,
#       'relative_error': 2.2871408319934588e-05,
#       'time': 0.012629801000002772,
#       'rank': 128}]},
#    {'shape': (256, 256),
#     'error_mean': np.float64(0.01561131770722568),
#     'error_std': np.float64(0.00039609540303755077),
#     'time_mean': np.float64(0.026343459900090238),
#     'time_std': np.float64(0.0005918795455065496),
#     'rank_mean': np.float64(256.0),
#     'rank_std': np.float64(0.0),
#     'raw_results': [{'shape': (256, 256),
#       'error': 0.01598038338124752,
#       'relative_error': 6.245514884137794e-05,
#       'time': 0.02773593200254254,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.014893372543156147,
#       'relative_error': 5.821592979558896e-05,
#       'time': 0.026397991998237558,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.01572582498192787,
#       'relative_error': 6.154054716314728e-05,
#       'time': 0.025518727998132817,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.015288214199244976,
#       'relative_error': 5.9755919927412166e-05,
#       'time': 0.026441523001267342,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.015550684183835983,
#       'relative_error': 6.0984626149973475e-05,
#       'time': 0.026898136999079725,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.015159402042627335,
#       'relative_error': 5.9038965308723885e-05,
#       'time': 0.026733016999060055,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.015921160578727722,
#       'relative_error': 6.214367341324191e-05,
#       'time': 0.025782732001971453,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.015337849967181683,
#       'relative_error': 5.975994838202338e-05,
#       'time': 0.026711907998105744,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.01587824337184429,
#       'relative_error': 6.212002371010756e-05,
#       'time': 0.02703210900290287,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.015386880375444889,
#       'relative_error': 5.9941781279396315e-05,
#       'time': 0.025670524999441113,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.01557100284844637,
#       'relative_error': 6.0909830012787744e-05,
#       'time': 0.026942136999423383,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.015510302037000656,
#       'relative_error': 6.0639992758687845e-05,
#       'time': 0.026736300002085045,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.016070950776338577,
#       'relative_error': 6.24815549907327e-05,
#       'time': 0.026435987998411292,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.016024691984057426,
#       'relative_error': 6.276048411937583e-05,
#       'time': 0.025623711000662297,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.015184064395725727,
#       'relative_error': 5.950628547102258e-05,
#       'time': 0.026277528999344213,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.014873295091092587,
#       'relative_error': 5.826401379645795e-05,
#       'time': 0.02643458000238752,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.015838485211133957,
#       'relative_error': 6.199247870583871e-05,
#       'time': 0.025409899000806035,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.016269557178020477,
#       'relative_error': 6.35945663913505e-05,
#       'time': 0.026279405999957817,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.015639305114746094,
#       'relative_error': 6.105463692673796e-05,
#       'time': 0.026237655998556875,
#       'rank': 256},
#      {'shape': (256, 256),
#       'error': 0.016122683882713318,
#       'relative_error': 6.306888327991721e-05,
#       'time': 0.025569388999429066,
#       'rank': 256}]},
#    {'shape': (512, 512),
#     'error_mean': np.float64(0.08289592675864696),
#     'error_std': np.float64(0.0016445501477625752),
#     'time_mean': np.float64(0.06759568139987096),
#     'time_std': np.float64(0.0011852272936700894),
#     'rank_mean': np.float64(512.0),
#     'rank_std': np.float64(0.0),
#     'raw_results': [{'shape': (512, 512),
#       'error': 0.08364269137382507,
#       'relative_error': 0.00016269216893853477,
#       'time': 0.06628825499865343,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.08181172609329224,
#       'relative_error': 0.0001601273418147613,
#       'time': 0.06681579400174087,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.08248033374547958,
#       'relative_error': 0.00016130706830117875,
#       'time': 0.06486325099831447,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.08190450817346573,
#       'relative_error': 0.00015985214880749837,
#       'time': 0.0680737090006005,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.08358967304229736,
#       'relative_error': 0.000163382887805144,
#       'time': 0.06867395700101042,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.08527898043394089,
#       'relative_error': 0.0001662173189479719,
#       'time': 0.06861813499926939,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.0825302004814148,
#       'relative_error': 0.00016133340627645415,
#       'time': 0.06630936399960774,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.08487600833177567,
#       'relative_error': 0.00016623643665042835,
#       'time': 0.0669629010008066,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.080396369099617,
#       'relative_error': 0.0001571120452404518,
#       'time': 0.06712623899875325,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.0830284133553505,
#       'relative_error': 0.00016207624443541018,
#       'time': 0.06854870999814011,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.0802135318517685,
#       'relative_error': 0.00015687855767099323,
#       'time': 0.067030074998911,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.0840970128774643,
#       'relative_error': 0.0001639278397448691,
#       'time': 0.06724473099893657,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.08569703251123428,
#       'relative_error': 0.0001669584367015115,
#       'time': 0.06908028399993782,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.0824858546257019,
#       'relative_error': 0.0001608948934764176,
#       'time': 0.06669204799982253,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.0820416510105133,
#       'relative_error': 0.00016024877496833878,
#       'time': 0.06675453100251616,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.08621606230735779,
#       'relative_error': 0.00016843861609751302,
#       'time': 0.0675340670022706,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.08093470335006714,
#       'relative_error': 0.00015799291024345532,
#       'time': 0.06783709899900714,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.08209510147571564,
#       'relative_error': 0.00016060747215593328,
#       'time': 0.06990954199864063,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.08304674923419952,
#       'relative_error': 0.00016228013324264914,
#       'time': 0.06837533300131327,
#       'rank': 512},
#      {'shape': (512, 512),
#       'error': 0.0815519317984581,
#       'relative_error': 0.0001596567339968362,
#       'time': 0.06917560299916659,
#       'rank': 512}]},
#    {'shape': (1024, 1024),
#     'error_mean': np.float64(0.3220638960599899),
#     'error_std': np.float64(0.005874173927480159),
#     'time_mean': np.float64(0.18795422410039464),
#     'time_std': np.float64(0.003624621971556317),
#     'rank_mean': np.float64(1024.0),
#     'rank_std': np.float64(0.0),
#     'raw_results': [{'shape': (1024, 1024),
#       'error': 0.3170032501220703,
#       'relative_error': 0.0003096119636860064,
#       'time': 0.17572481699971831,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.3369753658771515,
#       'relative_error': 0.00032914326684246696,
#       'time': 0.18096425200201338,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.31614023447036743,
#       'relative_error': 0.000308536313338906,
#       'time': 0.18397547899803612,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.32230299711227417,
#       'relative_error': 0.0003150888584602677,
#       'time': 0.1892154679990199,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.322518914937973,
#       'relative_error': 0.00031510489149158934,
#       'time': 0.18922621399906348,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.31553152203559875,
#       'relative_error': 0.00030841596808443204,
#       'time': 0.19003135900129564,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.31823813915252686,
#       'relative_error': 0.0003107375373581347,
#       'time': 0.18905072600318817,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.32454562187194824,
#       'relative_error': 0.0003167905188171832,
#       'time': 0.19062025700259255,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.3144102692604065,
#       'relative_error': 0.0003069672868165144,
#       'time': 0.1875228099997912,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.3175088167190552,
#       'relative_error': 0.00030990402465886854,
#       'time': 0.18829417199958698,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.32016339898109436,
#       'relative_error': 0.00031271041649117695,
#       'time': 0.18954803499946138,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.3185370862483978,
#       'relative_error': 0.0003112243957003285,
#       'time': 0.1888046959975327,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.32195207476615906,
#       'relative_error': 0.00031457633117219736,
#       'time': 0.18805189200065797,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.33013975620269775,
#       'relative_error': 0.00032224176474648095,
#       'time': 0.18799556299927644,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.31500595808029175,
#       'relative_error': 0.0003075711978067457,
#       'time': 0.18909824500224204,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.32814207673072815,
#       'relative_error': 0.00032066778126061866,
#       'time': 0.19064134600193938,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.3200465142726898,
#       'relative_error': 0.00031246485512736257,
#       'time': 0.18949039400104084,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.32537636160850525,
#       'relative_error': 0.0003177621149341538,
#       'time': 0.18914398299966706,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.3292054235935211,
#       'relative_error': 0.00032158997896410043,
#       'time': 0.19060601000091992,
#       'rank': 1024},
#      {'shape': (1024, 1024),
#       'error': 0.32753413915634155,
#       'relative_error': 0.000320037079148851,
#       'time': 0.19107876400084933,
#       'rank': 1024}]},
#    {'shape': (2048, 2048),
#     'error_mean': np.float64(1.340328758955002),
#     'error_std': np.float64(0.028141192440005864),
#     'time_mean': np.float64(0.5548317292499633),
#     'time_std': np.float64(0.07049189237282713),
#     'rank_mean': np.float64(2048.0),
#     'rank_std': np.float64(0.0),
#     'raw_results': [{'shape': (2048, 2048),
#       'error': 1.3345310688018799,
#       'relative_error': 0.0006519603046561478,
#       'time': 0.42424061600104324,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3244200944900513,
#       'relative_error': 0.0006465862903581214,
#       'time': 0.420124260999728,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3312301635742188,
#       'relative_error': 0.000650110129781933,
#       'time': 0.4495072190002247,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3220915794372559,
#       'relative_error': 0.0006455322133148533,
#       'time': 0.48594964900257764,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3449337482452393,
#       'relative_error': 0.0006568137485199227,
#       'time': 0.500009207000403,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3223001956939697,
#       'relative_error': 0.0006456891068637008,
#       'time': 0.49857459199847654,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3274363279342651,
#       'relative_error': 0.0006478345915135095,
#       'time': 0.5134075650021259,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3027640581130981,
#       'relative_error': 0.000636284334637303,
#       'time': 0.5372867480000423,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3156580924987793,
#       'relative_error': 0.0006424099526781747,
#       'time': 0.5574400699988473,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3710441589355469,
#       'relative_error': 0.0006696748119884952,
#       'time': 0.568353782997292,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3312336206436157,
#       'relative_error': 0.000650190462212461,
#       'time': 0.5727328079992731,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.345036268234253,
#       'relative_error': 0.0006568799098902823,
#       'time': 0.5828352370008361,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3346409797668457,
#       'relative_error': 0.0006516714651490335,
#       'time': 0.5990317079995293,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.418279767036438,
#       'relative_error': 0.0006925069519557362,
#       'time': 0.6143484590029402,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.330062747001648,
#       'relative_error': 0.0006496316847111565,
#       'time': 0.6155414589993597,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3292986154556274,
#       'relative_error': 0.0006491215779120422,
#       'time': 0.6277235309971729,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3562226295471191,
#       'relative_error': 0.0006620745943799516,
#       'time': 0.6207907720017829,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3766449689865112,
#       'relative_error': 0.0006721739805157932,
#       'time': 0.6280611309994129,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3868935108184814,
#       'relative_error': 0.0006768715816260268,
#       'time': 0.6367998319983599,
#       'rank': 2048},
#      {'shape': (2048, 2048),
#       'error': 1.3018525838851929,
#       'relative_error': 0.0006355451224561423,
#       'time': 0.6438759379998373,
#       'rank': 2048}]},
#    {'shape': (4096, 4096),
#     'error_mean': np.float64(4.506244730949402),
#     'error_std': np.float64(0.10757889403505494),
#     'time_mean': np.float64(4.527560319050099),
#     'time_std': np.float64(0.03472318481623029),
#     'rank_mean': np.float64(4096.0),
#     'rank_std': np.float64(0.0),
#     'raw_results': [{'shape': (4096, 4096),
#       'error': 4.513178825378418,
#       'relative_error': 0.0011016879735040366,
#       'time': 4.543974453001283,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.62548828125,
#       'relative_error': 0.0011295000480809557,
#       'time': 4.513434654996672,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.6933512687683105,
#       'relative_error': 0.0011457168387216604,
#       'time': 4.527569715999562,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.366876602172852,
#       'relative_error': 0.0010659235914421124,
#       'time': 4.555177725000249,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.551854610443115,
#       'relative_error': 0.0011114729591470837,
#       'time': 4.55332401400301,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.505936145782471,
#       'relative_error': 0.0010997444849626685,
#       'time': 4.568598778998421,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.6008758544921875,
#       'relative_error': 0.0011232720885428818,
#       'time': 4.546719801001018,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.502471446990967,
#       'relative_error': 0.0010995596273920643,
#       'time': 4.523312540000916,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.40898323059082,
#       'relative_error': 0.0010764865437954923,
#       'time': 4.465262317000452,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.381084442138672,
#       'relative_error': 0.0010693846142981963,
#       'time': 4.492528002996551,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.340509414672852,
#       'relative_error': 0.0010595014386235364,
#       'time': 4.535216644999309,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.391801834106445,
#       'relative_error': 0.0010719552812485029,
#       'time': 4.496222284000396,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.712558269500732,
#       'relative_error': 0.001150168102504402,
#       'time': 4.591690728000685,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.600464344024658,
#       'relative_error': 0.0011233700198767945,
#       'time': 4.5297389939987625,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.445061683654785,
#       'relative_error': 0.0010849050878680888,
#       'time': 4.492920346001483,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.45482873916626,
#       'relative_error': 0.0010871386417456606,
#       'time': 4.464927936001914,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.574757099151611,
#       'relative_error': 0.0011168519708797356,
#       'time': 4.488221471001452,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.508725166320801,
#       'relative_error': 0.001100612358765261,
#       'time': 4.527928202998737,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.5762200355529785,
#       'relative_error': 0.0011175001256831605,
#       'time': 4.572997300001589,
#       'rank': 4096},
#      {'shape': (4096, 4096),
#       'error': 4.369867324829102,
#       'relative_error': 0.00106690398367174,
#       'time': 4.561440470999514,
#       'rank': 4096}]},
#    {'shape': (256, 16),
#     'error_mean': np.float64(0.0001714799007459078),
#     'error_std': np.float64(2.179681965738316e-05),
#     'time_mean': np.float64(0.003366137899683963),
#     'time_std': np.float64(0.00021227581917749566),
#     'rank_mean': np.float64(16.0),
#     'rank_std': np.float64(0.0),
#     'raw_results': [{'shape': (256, 16),
#       'error': 0.0001495491451350972,
#       'relative_error': 2.2943881049543775e-06,
#       'time': 0.003926585999579402,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.0001911925501190126,
#       'relative_error': 3.0316228182089815e-06,
#       'time': 0.0035852629989676643,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.0001725006732158363,
#       'relative_error': 2.7161630732474303e-06,
#       'time': 0.003440758999204263,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00017215029220096767,
#       'relative_error': 2.6699006256524437e-06,
#       'time': 0.003672326001833426,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00016060257621575147,
#       'relative_error': 2.5041863372168883e-06,
#       'time': 0.0033629999998083804,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00020212720846757293,
#       'relative_error': 3.1816604735416797e-06,
#       'time': 0.003359581998665817,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00018122195615433156,
#       'relative_error': 2.8133965248120244e-06,
#       'time': 0.003582414999982575,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00018740493396762758,
#       'relative_error': 2.948161364932231e-06,
#       'time': 0.003393286999198608,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00016626017168164253,
#       'relative_error': 2.5916100424472924e-06,
#       'time': 0.003396989999600919,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00015212157450150698,
#       'relative_error': 2.3578791249460634e-06,
#       'time': 0.0035452920019451994,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.0001943672978086397,
#       'relative_error': 3.018452868142667e-06,
#       'time': 0.0031673209996370133,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00015281917876563966,
#       'relative_error': 2.3595434548696914e-06,
#       'time': 0.003222957999241771,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00015927165804896504,
#       'relative_error': 2.5019287564345244e-06,
#       'time': 0.00318460099879303,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00015164504293352365,
#       'relative_error': 2.3784439060130983e-06,
#       'time': 0.0032969189996947534,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00017779006157070398,
#       'relative_error': 2.7764448962876935e-06,
#       'time': 0.0032967299994197674,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00020105307339690626,
#       'relative_error': 3.153198596624402e-06,
#       'time': 0.003098581997619476,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.0001240699930349365,
#       'relative_error': 1.934368224588375e-06,
#       'time': 0.0030446540004049893,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00014037408982403576,
#       'relative_error': 2.20313840243042e-06,
#       'time': 0.0030977269998402335,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00019315542886033654,
#       'relative_error': 3.0442407496208005e-06,
#       'time': 0.003378760000487091,
#       'rank': 16},
#      {'shape': (256, 16),
#       'error': 0.00019992110901512206,
#       'relative_error': 3.092085334567861e-06,
#       'time': 0.0032690059997548815,
#       'rank': 16}]},
#    {'shape': (256, 32),
#     'error_mean': np.float64(0.0003764204288017936),
#     'error_std': np.float64(3.334312999391943e-05),
#     'time_mean': np.float64(0.004029469799388607),
#     'time_std': np.float64(0.0003084817405939003),
#     'rank_mean': np.float64(32.0),
#     'rank_std': np.float64(0.0),
#     'raw_results': [{'shape': (256, 32),
#       'error': 0.0003752429911401123,
#       'relative_error': 4.146220939922842e-06,
#       'time': 0.0051969319974887185,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.0003888844803441316,
#       'relative_error': 4.294879540722218e-06,
#       'time': 0.003959910998673877,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.0003719510277733207,
#       'relative_error': 4.107770286792266e-06,
#       'time': 0.0040665319975232705,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.0003542034246493131,
#       'relative_error': 3.912004147391288e-06,
#       'time': 0.0039429159987776075,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.00037730587064288557,
#       'relative_error': 4.1663375508367e-06,
#       'time': 0.0038016389989934396,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.0003828807675745338,
#       'relative_error': 4.184843784087462e-06,
#       'time': 0.003929814000002807,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.0003709997399710119,
#       'relative_error': 4.170552428395491e-06,
#       'time': 0.0037576809991151094,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.00039584538899362087,
#       'relative_error': 4.408582575405137e-06,
#       'time': 0.004034251996927196,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.00035578309325501323,
#       'relative_error': 3.958642924627715e-06,
#       'time': 0.003743629997188691,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.0004500115755945444,
#       'relative_error': 4.960212223472921e-06,
#       'time': 0.003758344999369001,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.0003736834623850882,
#       'relative_error': 4.16119229820053e-06,
#       'time': 0.003892371001711581,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.000351688388036564,
#       'relative_error': 3.908932129827486e-06,
#       'time': 0.004195256002276437,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.00035648082848638296,
#       'relative_error': 3.889242475799509e-06,
#       'time': 0.003961854999943171,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.00041408458491787314,
#       'relative_error': 4.593353086921682e-06,
#       'time': 0.003964981999160955,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.0004420146578922868,
#       'relative_error': 4.788160427820397e-06,
#       'time': 0.004033569999592146,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.00038915328332223,
#       'relative_error': 4.275332231033228e-06,
#       'time': 0.003962259001127677,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.00030850322218611836,
#       'relative_error': 3.3911466457547412e-06,
#       'time': 0.003944808999222005,
#       'rank': 32},
#      {'shape': (256, 32),
#       'error': 0.00036133104003965855,
# ...
#      'relative_error': 6.388863507340688e-05,
#      'time': 0.013354639999306528,
#      'rank': 256},
#     {'shape': (256, 256),
#      'error': 0.017129912972450256,
#      'relative_error': 6.669029286985821e-05,
#      'time': 0.013752804003161145,
#      'rank': 256},
#     {'shape': (256, 256),
#      'error': 0.01645071804523468,
#      'relative_error': 6.440040632543882e-05,
#      'time': 0.013308576002600603,
#      'rank': 256},
#     {'shape': (256, 256),
#      'error': 0.01704985275864601,
#      'relative_error': 6.633586082333191e-05,
#      'time': 0.013633092999953078,
#      'rank': 256},
#     {'shape': (256, 256),
#      'error': 0.017003146931529045,
#      'relative_error': 6.63949009279337e-05,
#      'time': 0.012633084999833954,
#      'rank': 256},
#     {'shape': (256, 256),
#      'error': 0.016440289095044136,
#      'relative_error': 6.42742111083717e-05,
#      'time': 0.01270419900174602,
#      'rank': 256},
#     {'shape': (256, 256),
#      'error': 0.016834154725074768,
#      'relative_error': 6.565068182292886e-05,
#      'time': 0.012554559001728194,
#      'rank': 256},
#     {'shape': (256, 256),
#      'error': 0.017093650996685028,
#      'relative_error': 6.660888315353436e-05,
#      'time': 0.012254716999450466,
#      'rank': 256},
#     {'shape': (256, 256),
#      'error': 0.016582272946834564,
#      'relative_error': 6.471865434444851e-05,
#      'time': 0.01236119999884977,
#      'rank': 256},
#     {'shape': (256, 256),
#      'error': 0.016868606209754944,
#      'relative_error': 6.597818899445986e-05,
#      'time': 0.012330333000136307,
#      'rank': 256},
#     {'shape': (256, 256),
#      'error': 0.016273414716124535,
#      'relative_error': 6.358625630907918e-05,
#      'time': 0.011227594997762935,
#      'rank': 256},
#     {'shape': (256, 256),
#      'error': 0.01655293069779873,
#      'relative_error': 6.457123353586628e-05,
#      'time': 0.01247359300032258,
#      'rank': 256}]},
#   {'shape': (512, 512),
#    'error_mean': np.float64(0.08556229956448078),
#    'error_std': np.float64(0.001578892220058593),
#    'time_mean': np.float64(0.030181054450076773),
#    'time_std': np.float64(0.0014270745785560078),
#    'rank_mean': np.float64(512.0),
#    'rank_std': np.float64(0.0),
#    'raw_results': [{'shape': (512, 512),
#      'error': 0.08462731540203094,
#      'relative_error': 0.0001655928299816933,
#      'time': 0.03290475100220647,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08337514847517014,
#      'relative_error': 0.00016282085259013818,
#      'time': 0.03251043199998094,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08286856859922409,
#      'relative_error': 0.00016168668058353687,
#      'time': 0.03154504300255212,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08524702489376068,
#      'relative_error': 0.0001668352222098176,
#      'time': 0.03129736400296679,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08694764971733093,
#      'relative_error': 0.00016972044984383768,
#      'time': 0.031164893000095617,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08455586433410645,
#      'relative_error': 0.00016509106004163732,
#      'time': 0.03190371099844924,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08633847534656525,
#      'relative_error': 0.00016865380999404704,
#      'time': 0.030801629000052344,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08386529237031937,
#      'relative_error': 0.0001640837081543608,
#      'time': 0.03196056399974623,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08677811920642853,
#      'relative_error': 0.0001692656073467452,
#      'time': 0.029217321000032825,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08464545011520386,
#      'relative_error': 0.00016527670591970052,
#      'time': 0.028915507999045076,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08461813628673553,
#      'relative_error': 0.0001654216694723745,
#      'time': 0.02942325199910556,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08714120090007782,
#      'relative_error': 0.00017006180898724216,
#      'time': 0.03018083400093019,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08537383377552032,
#      'relative_error': 0.00016661172271508227,
#      'time': 0.028930518998095067,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.0880320742726326,
#      'relative_error': 0.00017245635404009797,
#      'time': 0.02892385899758665,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08858630061149597,
#      'relative_error': 0.00017313398473412135,
#      'time': 0.03029473000060534,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08763458579778671,
#      'relative_error': 0.0001711297207955296,
#      'time': 0.028152486000180943,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08693017065525055,
#      'relative_error': 0.00016990602335460283,
#      'time': 0.028780222000932554,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08498353511095047,
#      'relative_error': 0.00016600886722074632,
#      'time': 0.02872139900136972,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08436717092990875,
#      'relative_error': 0.00016459963989482758,
#      'time': 0.028909315999044338,
#      'rank': 512},
#     {'shape': (512, 512),
#      'error': 0.08433007448911667,
#      'relative_error': 0.00016428663890748348,
#      'time': 0.029083255998557433,
#      'rank': 512}]},
#   {'shape': (1024, 1024),
#    'error_mean': np.float64(0.31220990121364595),
#    'error_std': np.float64(0.0074723878095981485),
#    'time_mean': np.float64(0.08315503495014127),
#    'time_std': np.float64(0.002100081502679923),
#    'rank_mean': np.float64(1024.0),
#    'rank_std': np.float64(0.0),
#    'raw_results': [{'shape': (1024, 1024),
#      'error': 0.3032158315181732,
#      'relative_error': 0.00029623748951882747,
#      'time': 0.0882349109997449,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.3072006106376648,
#      'relative_error': 0.0003000518532573542,
#      'time': 0.0880756750011642,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.32211923599243164,
#      'relative_error': 0.0003145045929897247,
#      'time': 0.0843570870019903,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.31171730160713196,
#      'relative_error': 0.0003040265651548202,
#      'time': 0.08460680300049717,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.3110670745372772,
#      'relative_error': 0.00030422258625811604,
#      'time': 0.08328256300228531,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.2978661358356476,
#      'relative_error': 0.0002908395142366277,
#      'time': 0.0831498340012331,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.31353962421417236,
#      'relative_error': 0.00030630867182597965,
#      'time': 0.08270332800020697,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.3082578480243683,
#      'relative_error': 0.00030105954086265344,
#      'time': 0.08231416399939917,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.3272353410720825,
#      'relative_error': 0.00031966680414601483,
#      'time': 0.08507466399896657,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.30480995774269104,
#      'relative_error': 0.0002975244937685111,
#      'time': 0.08362211400162778,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.3038678467273712,
#      'relative_error': 0.0002968578061957371,
#      'time': 0.0827479690015025,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.32009753584861755,
#      'relative_error': 0.0003126439804644981,
#      'time': 0.08377895699959481,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.31785768270492554,
#      'relative_error': 0.00031052266505262206,
#      'time': 0.08273628000097233,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.32002437114715576,
#      'relative_error': 0.00031250379489655976,
#      'time': 0.0805643109997618,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.315280944108963,
#      'relative_error': 0.0003077101916019136,
#      'time': 0.08122979099789518,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.31470349431037903,
#      'relative_error': 0.0003072131121145538,
#      'time': 0.08142400499855285,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.32054445147514343,
#      'relative_error': 0.0003130771300661839,
#      'time': 0.08159944100043504,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.3040435314178467,
#      'relative_error': 0.00029695324703191264,
#      'time': 0.08195924200117588,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.3138415813446045,
#      'relative_error': 0.0003065019411416281,
#      'time': 0.08149211699856096,
#      'rank': 1024},
#     {'shape': (1024, 1024),
#      'error': 0.30690762400627136,
#      'relative_error': 0.0002996941840127535,
#      'time': 0.08014744299725862,
#      'rank': 1024}]},
#   {'shape': (2048, 2048),
#    'error_mean': np.float64(1.2571813821792603),
#    'error_std': np.float64(0.03662264021107116),
#    'time_mean': np.float64(0.2453532969502703),
#    'time_std': np.float64(0.036458649293701594),
#    'rank_mean': np.float64(2048.0),
#    'rank_std': np.float64(0.0),
#    'raw_results': [{'shape': (2048, 2048),
#      'error': 1.2775253057479858,
#      'relative_error': 0.0006240512837557862,
#      'time': 0.32983153100212803,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.3423686027526855,
#      'relative_error': 0.0006554674450494511,
#      'time': 0.3116046679970168,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2505947351455688,
#      'relative_error': 0.0006107405761798246,
#      'time': 0.289573106001626,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.3052568435668945,
#      'relative_error': 0.000637556689055092,
#      'time': 0.2837127269995108,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2064260244369507,
#      'relative_error': 0.000589367305119608,
#      'time': 0.2710710499995912,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.1737831830978394,
#      'relative_error': 0.0005729939697427519,
#      'time': 0.2643703390021983,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.218471884727478,
#      'relative_error': 0.0005946581787610378,
#      'time': 0.25732449399947654,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2766436338424683,
#      'relative_error': 0.0006231620609635553,
#      'time': 0.24752121300116414,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2626674175262451,
#      'relative_error': 0.000616454298974246,
#      'time': 0.24766184499821975,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2861874103546143,
#      'relative_error': 0.0006281698405678304,
#      'time': 0.24617905400009477,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2952110767364502,
#      'relative_error': 0.0006326216641249397,
#      'time': 0.2359102709997387,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2372241020202637,
#      'relative_error': 0.0006036048229445518,
#      'time': 0.23300576100155013,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2337720394134521,
#      'relative_error': 0.0006028506095915242,
#      'time': 0.22670275900236447,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2524900436401367,
#      'relative_error': 0.0006117906463048862,
#      'time': 0.22461271400243277,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.270195484161377,
#      'relative_error': 0.0006202191081401064,
#      'time': 0.2155651629982458,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.229251503944397,
#      'relative_error': 0.0005998964344753792,
#      'time': 0.21169593800004805,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2549452781677246,
#      'relative_error': 0.0006128058433702119,
#      'time': 0.20847206699909293,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2496540546417236,
#      'relative_error': 0.0006101739879975233,
#      'time': 0.20774981000067783,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2373327016830444,
#      'relative_error': 0.0006038668222720951,
#      'time': 0.19468405400039046,
#      'rank': 2048},
#     {'shape': (2048, 2048),
#      'error': 1.2836263179779053,
#      'relative_error': 0.0006270912129352768,
#      'time': 0.19981737499983865,
#      'rank': 2048}]},
#   {'shape': (4096, 4096),
#    'error_mean': np.float64(4.144703388214111),
#    'error_std': np.float64(0.1422278139709592),
#    'time_mean': np.float64(2.692718088499896),
#    'time_std': np.float64(0.025417645744948054),
#    'rank_mean': np.float64(4096.0),
#    'rank_std': np.float64(0.0),
#    'raw_results': [{'shape': (4096, 4096),
#      'error': 4.0711870193481445,
#      'relative_error': 0.000994164297175414,
#      'time': 2.6516786350002803,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.15688943862915,
#      'relative_error': 0.0010149662521164728,
#      'time': 2.6702247799985344,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.161425590515137,
#      'relative_error': 0.0010157799053699893,
#      'time': 2.7358970349996525,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.1995625495910645,
#      'relative_error': 0.0010253432295765966,
#      'time': 2.715920462000213,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 3.969362258911133,
#      'relative_error': 0.0009688793037742802,
#      'time': 2.6784909130001324,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.2526655197143555,
#      'relative_error': 0.0010381087016643072,
#      'time': 2.7290524279997044,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 3.9077694416046143,
#      'relative_error': 0.0009538949450598813,
#      'time': 2.6846409650024725,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 3.832435369491577,
#      'relative_error': 0.0009356462510408384,
#      'time': 2.688974089000112,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.14999532699585,
#      'relative_error': 0.0010132668252664744,
#      'time': 2.7297856520017376,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.077661514282227,
#      'relative_error': 0.0009954378661796827,
#      'time': 2.7067470289985067,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.147213459014893,
#      'relative_error': 0.0010124078213543664,
#      'time': 2.6489116480006487,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.129636764526367,
#      'relative_error': 0.0010087086625304126,
#      'time': 2.6734026220001397,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.31184196472168,
#      'relative_error': 0.0010527308681044143,
#      'time': 2.6880456039980345,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.113205432891846,
#      'relative_error': 0.001004152543710765,
#      'time': 2.657434586999443,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.116143226623535,
#      'relative_error': 0.0010048233899228264,
#      'time': 2.708733862997178,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.418160438537598,
#      'relative_error': 0.001078465777136874,
#      'time': 2.702322921999439,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.4064154624938965,
#      'relative_error': 0.0010756029499767463,
#      'time': 2.685317389001284,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.240875244140625,
#      'relative_error': 0.0010352969931932716,
#      'time': 2.6775635049998527,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.041669845581055,
#      'relative_error': 0.00098684250234361,
#      'time': 2.7233232250000583,
#      'rank': 4096},
#     {'shape': (4096, 4096),
#      'error': 4.1899518966674805,
#      'relative_error': 0.0010227012025647675,
#      'time': 2.697894417000498,
#      'rank': 4096}]}])
