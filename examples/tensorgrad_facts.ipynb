# %% [markdown]
# ![image.png](attachment:image.png)
# Данные запуска с пиком перплексии
# array(["perebor_{'rank': 256, 'sparse_ratio': 0.05, 'lambda_sparse': 0.05, 'update_gap': 40, 'update_gap_mode': 'fixed', 'optimizer_type': 'ultg'}"],
#       dtype=object)
#
# На самом ранг 128 (что мало для квена, тестировалось для parallel в т. ч.), но почему-то на этих параметрах взорвалось. Как видим, после update_gap=40 примерно, возможно это связано.

# %% [markdown]
# Эксперименты c ultg qwen-exp-perebor-fixed-glazkov от 06.03 запускались не правильно, rank передавался в rank, а не second_rank как должен (тк первый проектор unstruct-sparse). Поэтому для всех них дефолтный ранг 128.
